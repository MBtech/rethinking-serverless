# %%
import glob 
import os 
import numpy as np
import pandas as pd
from utils import *

# %% [markdown]
# ## Settings and Paramters

# %%
CPU_LIMITS= [ '250m', '500m', '750m', '1000m', '1250m', '1500m', '1750m', '2000m' ]
MEMORY_LIMITS=[ '128Mi', '256Mi', '512Mi', '768Mi', '1024Mi' ]
instance_types = ['m5', 'm5a', 'c5', 'c5a', 'c6g', 'm6g']
benchmarks = {"transcode": "cats-1", "pigo-faceblur": "faces2", "pigo-face-detector": "faces2", "classifier": "bridge-8k-1920x1200", "linpack": "5000", "s3": "cats-1", "openfaas-ocr": "doc"}
calculate_cpu_mem_costs()
# Weights of execution time and execution cost objectives
weights = [(0.0, 1.0), (0.25, 0.75), (0.50, 0.50), (0.75, 0.25), (1.0, 0.0)]
thresholds =  [0.05, 0.1, 0.2]

# %% [markdown]
# ## Potential alternative configurations
# The following script gets the alternative configuration choices with different instance types that provides performance (as defined by the weighted objective function) within the thresholds mentioned above.

# %%
for benchmark in benchmarks.keys():
    data_name = benchmarks[benchmark]
    print(benchmark)
    runtimes, costs, configs = get_all_runtimes_costs_from_data(instance_types, CPU_LIMITS, MEMORY_LIMITS, benchmark, data_name, return_configs=True)
    
    for weight in weights:
        print(weight)
        dataframe = pd.DataFrame(columns = ['metric', 'memory', 'cpu'])

        runtime_weight = weight[0]
        cost_weight = weight[1]

        minimum_runtime, minimum_cost, _, _ = get_best_configuration(instance_types, CPU_LIMITS, MEMORY_LIMITS, benchmark, data_name, metric=str(runtime_weight)+'/'+str(cost_weight))

        for i in range(0, len(runtimes)):
            config = configs[i]
            runtime = runtimes[i]
            cost = costs[i]

            mem = config["memory"]
            cpu = config["cpu"]
            instance_type = config["instance_type"]

            metric_value =  ((runtime/minimum_runtime) * runtime_weight) + ((cost/minimum_cost) * cost_weight)

            dataframe = dataframe.append({'metric': metric_value, 'memory': mem, 
                                            'cpu': instance_type+ '_'+ cpu}, ignore_index=True)

        dataframe.sort_values(by=["metric"], inplace=True)
        best_config = dataframe.iloc[0]
        # print("Best configuration")
        print(best_config)
        
        for threshold in thresholds:
            count = 0 
            alternatives = []
            for index, row in dataframe.iterrows():
                if  (row["metric"]<= (1+threshold)*best_config["metric"]) and (row["cpu"].split("_")[0] != best_config["cpu"].split("_")[0]) and (row["cpu"].split("_")[0] not in alternatives):
                    alternatives.append(row["cpu"].split("_")[0])
                    count += 1
                    # print(row)
            print(alternatives)
            print("Number of instance types that are within " + str(threshold*100) + "% of the best configuration: " + str(count) + "\n\n")
# Out:
# transcode
# (0.0, 1.0)
# metric           1
# memory         512
# cpu       m6g_2000
# Name: 237, dtype: object
# ['c6g']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c6g', 'c5a']
# Number of instance types that are within 10.0% of the best configuration: 2
#
#
# ['c6g', 'c5a']
# Number of instance types that are within 20.0% of the best configuration: 2
#
#
# (0.25, 0.75)
# metric           1
# memory         512
# cpu       m6g_2000
# Name: 237, dtype: object
# ['c5a', 'c6g']
# Number of instance types that are within 5.0% of the best configuration: 2
#
#
# ['c5a', 'c6g']
# Number of instance types that are within 10.0% of the best configuration: 2
#
#
# ['c5a', 'c6g']
# Number of instance types that are within 20.0% of the best configuration: 2
#
#
# (0.5, 0.5)
# metric           1
# memory         512
# cpu       c5a_2000
# Name: 157, dtype: object
# ['m6g', 'c6g']
# Number of instance types that are within 5.0% of the best configuration: 2
#
#
# ['m6g', 'c6g']
# Number of instance types that are within 10.0% of the best configuration: 2
#
#
# ['m6g', 'c6g']
# Number of instance types that are within 20.0% of the best configuration: 2
#
#
# (0.75, 0.25)
# metric           1
# memory         768
# cpu       c5a_2000
# Name: 158, dtype: object
# []
# Number of instance types that are within 5.0% of the best configuration: 0
#
#
# ['m6g', 'c6g']
# Number of instance types that are within 10.0% of the best configuration: 2
#
#
# ['m6g', 'c6g']
# Number of instance types that are within 20.0% of the best configuration: 2
#
#
# (1.0, 0.0)
# metric           1
# memory        1024
# cpu       c5a_2000
# Name: 159, dtype: object
# []
# Number of instance types that are within 5.0% of the best configuration: 0
#
#
# []
# Number of instance types that are within 10.0% of the best configuration: 0
#
#
# ['c6g', 'm6g']
# Number of instance types that are within 20.0% of the best configuration: 2
#
#
# pigo-faceblur
# (0.0, 1.0)
# metric          1
# memory        256
# cpu       c5a_500
# Name: 126, dtype: object
# []
# Number of instance types that are within 5.0% of the best configuration: 0
#
#
# ['c5', 'm6g', 'm5']
# Number of instance types that are within 10.0% of the best configuration: 3
#
#
# ['c5', 'm6g', 'm5', 'c6g']
# Number of instance types that are within 20.0% of the best configuration: 4
#
#
# (0.25, 0.75)
# metric           1
# memory         256
# cpu       c5a_1000
# Name: 136, dtype: object
# []
# Number of instance types that are within 5.0% of the best configuration: 0
#
#
# ['c5']
# Number of instance types that are within 10.0% of the best configuration: 1
#
#
# ['c5', 'm5', 'm6g']
# Number of instance types that are within 20.0% of the best configuration: 3
#
#
# (0.5, 0.5)
# metric           1
# memory         256
# cpu       c5a_1000
# Name: 136, dtype: object
# ['c5']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c5']
# Number of instance types that are within 10.0% of the best configuration: 1
#
#
# ['c5', 'm5', 'm6g']
# Number of instance types that are within 20.0% of the best configuration: 3
#
#
# (0.75, 0.25)
# metric           1
# memory         256
# cpu       c5a_1000
# Name: 136, dtype: object
# ['c5']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c5']
# Number of instance types that are within 10.0% of the best configuration: 1
#
#
# ['c5', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 2
#
#
# (1.0, 0.0)
# metric          1
# memory        768
# cpu       c5_1000
# Name: 98, dtype: object
# ['c5a']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c5a', 'm5']
# Number of instance types that are within 10.0% of the best configuration: 2
#
#
# ['c5a', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 2
#
#
# pigo-face-detector
# (0.0, 1.0)
# metric           1
# memory         512
# cpu       m6g_1000
# Name: 217, dtype: object
# ['c5a']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c5a']
# Number of instance types that are within 10.0% of the best configuration: 1
#
#
# ['c5a', 'c5', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 3
#
#
# (0.25, 0.75)
# metric           1
# memory         512
# cpu       m6g_1000
# Name: 217, dtype: object
# ['c5a']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c5a']
# Number of instance types that are within 10.0% of the best configuration: 1
#
#
# ['c5a', 'c5', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 3
#
#
# (0.5, 0.5)
# metric           1
# memory         512
# cpu       m6g_1000
# Name: 217, dtype: object
# ['c5a', 'c5']
# Number of instance types that are within 5.0% of the best configuration: 2
#
#
# ['c5a', 'c5', 'm5']
# Number of instance types that are within 10.0% of the best configuration: 3
#
#
# ['c5a', 'c5', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 3
#
#
# (0.75, 0.25)
# metric           1
# memory         128
# cpu       c5a_1000
# Name: 135, dtype: object
# ['c5', 'm6g']
# Number of instance types that are within 5.0% of the best configuration: 2
#
#
# ['c5', 'm6g', 'm5']
# Number of instance types that are within 10.0% of the best configuration: 3
#
#
# ['c5', 'm6g', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 3
#
#
# (1.0, 0.0)
# metric          1
# memory        256
# cpu       c5_1000
# Name: 96, dtype: object
# ['c5a']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c5a', 'm5', 'm6g', 'm5a']
# Number of instance types that are within 10.0% of the best configuration: 4
#
#
# ['c5a', 'm5', 'm6g', 'm5a']
# Number of instance types that are within 20.0% of the best configuration: 4
#
#
# classifier
# (0.0, 1.0)
# metric          1
# memory       1024
# cpu       m6g_750
# Name: 214, dtype: object
# ['c6g']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c6g']
# Number of instance types that are within 10.0% of the best configuration: 1
#
#
# ['c6g', 'm5a', 'c5a', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 4
#
#
# (0.25, 0.75)
# metric           1
# memory        1024
# cpu       m6g_1000
# Name: 219, dtype: object
# ['c6g']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c6g']
# Number of instance types that are within 10.0% of the best configuration: 1
#
#
# ['c6g', 'c5a']
# Number of instance types that are within 20.0% of the best configuration: 2
#
#
# (0.5, 0.5)
# metric           1
# memory        1024
# cpu       m6g_1000
# Name: 219, dtype: object
# ['c6g']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c6g', 'c5a']
# Number of instance types that are within 10.0% of the best configuration: 2
#
#
# ['c6g', 'c5a', 'm5a', 'm5', 'c5']
# Number of instance types that are within 20.0% of the best configuration: 5
#
#
# (0.75, 0.25)
# metric           1
# memory        1024
# cpu       m6g_1000
# Name: 219, dtype: object
# ['c5a', 'c6g']
# Number of instance types that are within 5.0% of the best configuration: 2
#
#
# ['c5a', 'c6g', 'm5a', 'c5', 'm5']
# Number of instance types that are within 10.0% of the best configuration: 5
#
#
# ['c5a', 'c6g', 'm5a', 'c5', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 5
#
#
# (1.0, 0.0)
# metric           1
# memory        1024
# cpu       c5a_2000
# Name: 159, dtype: object
# ['m5a', 'c5', 'm5', 'm6g']
# Number of instance types that are within 5.0% of the best configuration: 4
#
#
# ['m5a', 'c5', 'm5', 'm6g', 'c6g']
# Number of instance types that are within 10.0% of the best configuration: 5
#
#
# ['m5a', 'c5', 'm5', 'm6g', 'c6g']
# Number of instance types that are within 20.0% of the best configuration: 5
#
#
# linpack
# (0.0, 1.0)
# metric           1
# memory         512
# cpu       c5a_1000
# Name: 137, dtype: object
# ['m5a']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['m5a']
# Number of instance types that are within 10.0% of the best configuration: 1
#
#
# ['m5a', 'c5', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 3
#
#
# (0.25, 0.75)
# metric           1
# memory         512
# cpu       c5a_1000
# Name: 137, dtype: object
# []
# Number of instance types that are within 5.0% of the best configuration: 0
#
#
# ['m5a', 'c5']
# Number of instance types that are within 10.0% of the best configuration: 2
#
#
# ['m5a', 'c5', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 3
#
#
# (0.5, 0.5)
# metric           1
# memory         768
# cpu       c5a_1000
# Name: 138, dtype: object
# []
# Number of instance types that are within 5.0% of the best configuration: 0
#
#
# ['c5', 'm5a']
# Number of instance types that are within 10.0% of the best configuration: 2
#
#
# ['c5', 'm5a', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 3
#
#
# (0.75, 0.25)
# metric           1
# memory         768
# cpu       c5a_1000
# Name: 138, dtype: object
# ['c5']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c5']
# Number of instance types that are within 10.0% of the best configuration: 1
#
#
# ['c5', 'm5a', 'm5', 'c6g']
# Number of instance types that are within 20.0% of the best configuration: 4
#
#
# (1.0, 0.0)
# metric          1
# memory        768
# cpu       c5_2000
# Name: 118, dtype: object
# ['c5a', 'c6g']
# Number of instance types that are within 5.0% of the best configuration: 2
#
#
# ['c5a', 'c6g']
# Number of instance types that are within 10.0% of the best configuration: 2
#
#
# ['c5a', 'c6g', 'm5', 'm5a']
# Number of instance types that are within 20.0% of the best configuration: 4
#
#
# s3
# (0.0, 1.0)
# metric          1
# memory        128
# cpu       m6g_250
# Name: 200, dtype: object
# []
# Number of instance types that are within 5.0% of the best configuration: 0
#
#
# []
# Number of instance types that are within 10.0% of the best configuration: 0
#
#
# ['c5a', 'c6g', 'm5a']
# Number of instance types that are within 20.0% of the best configuration: 3
#
#
# (0.25, 0.75)
# metric          1
# memory        128
# cpu       m6g_250
# Name: 200, dtype: object
# []
# Number of instance types that are within 5.0% of the best configuration: 0
#
#
# ['c5a']
# Number of instance types that are within 10.0% of the best configuration: 1
#
#
# ['c5a', 'm5a', 'c6g', 'c5', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 5
#
#
# (0.5, 0.5)
# metric          1
# memory        128
# cpu       m6g_500
# Name: 205, dtype: object
# ['c5a']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c5a', 'c6g', 'm5a', 'c5']
# Number of instance types that are within 10.0% of the best configuration: 4
#
#
# ['c5a', 'c6g', 'm5a', 'c5', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 5
#
#
# (0.75, 0.25)
# metric          1
# memory        128
# cpu       m6g_750
# Name: 210, dtype: object
# []
# Number of instance types that are within 5.0% of the best configuration: 0
#
#
# ['m5', 'c5a', 'm5a', 'c5']
# Number of instance types that are within 10.0% of the best configuration: 4
#
#
# ['m5', 'c5a', 'm5a', 'c5', 'c6g']
# Number of instance types that are within 20.0% of the best configuration: 5
#
#
# (1.0, 0.0)
# metric           1
# memory         256
# cpu       c5a_2000
# Name: 156, dtype: object
# ['c5', 'm5', 'm6g']
# Number of instance types that are within 5.0% of the best configuration: 3
#
#
# ['c5', 'm5', 'm6g', 'm5a', 'c6g']
# Number of instance types that are within 10.0% of the best configuration: 5
#
#
# ['c5', 'm5', 'm6g', 'm5a', 'c6g']
# Number of instance types that are within 20.0% of the best configuration: 5
#
#
# openfaas-ocr
# (0.0, 1.0)
# metric           1
# memory         256
# cpu       m6g_2000
# Name: 236, dtype: object
# ['c6g']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c6g']
# Number of instance types that are within 10.0% of the best configuration: 1
#
#
# ['c6g', 'm5a']
# Number of instance types that are within 20.0% of the best configuration: 2
#
#
# (0.25, 0.75)
# metric           1
# memory         256
# cpu       m6g_2000
# Name: 236, dtype: object
# ['c6g']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c6g']
# Number of instance types that are within 10.0% of the best configuration: 1
#
#
# ['c6g', 'm5a']
# Number of instance types that are within 20.0% of the best configuration: 2
#
#
# (0.5, 0.5)
# metric           1
# memory         256
# cpu       m6g_2000
# Name: 236, dtype: object
# ['c6g']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['c6g']
# Number of instance types that are within 10.0% of the best configuration: 1
#
#
# ['c6g', 'm5a', 'c5', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 4
#
#
# (0.75, 0.25)
# metric           1
# memory         256
# cpu       c6g_2000
# Name: 196, dtype: object
# ['m6g']
# Number of instance types that are within 5.0% of the best configuration: 1
#
#
# ['m6g', 'c5', 'm5a']
# Number of instance types that are within 10.0% of the best configuration: 3
#
#
# ['m6g', 'c5', 'm5a', 'm5']
# Number of instance types that are within 20.0% of the best configuration: 4
#
#
# (1.0, 0.0)
# metric          1
# memory        512
# cpu       c5_2000
# Name: 117, dtype: object
# ['c6g', 'm6g']
# Number of instance types that are within 5.0% of the best configuration: 2
#
#
# ['c6g', 'm6g', 'm5a', 'm5']
# Number of instance types that are within 10.0% of the best configuration: 4
#
#
# ['c6g', 'm6g', 'm5a', 'm5', 'c5a']
# Number of instance types that are within 20.0% of the best configuration: 5
